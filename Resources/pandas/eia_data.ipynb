# %%
import pandas as pd
import requests
from pprint import pprint
import json
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
use_us = pd.read_csv("data/use_US.csv")
pr_us = pd.read_csv("data/pr_US.csv")
tot_energy = pd.read_csv("data/Total Energy Consumed per Capita-StateRankings.csv")
seds = pd.read_csv("data/Complete_SEDS.csv")

# %%
pr_us
# Out:
#     Data_Status State    MSN    1970    1971    1972     1973     1974  \
# 0         2018F    US  ARICD    0.68    0.79    0.82     0.84     1.60
# 1         2018F    US  ARICV  730.80  878.00  928.10  1057.80  1865.40
# 2         2018F    US  ARTCD    0.68    0.79    0.82     0.84     1.60
# 3         2018F    US  ARTCV  730.80  878.00  928.10  1057.80  1865.40
# 4         2018F    US  ARTXD    0.68    0.79    0.82     0.84     1.60
# ..          ...   ...    ...     ...     ...     ...      ...      ...
# 299       2018F    US  WWTCV  452.00  461.10  491.80   517.90   559.70
# 300       2018F    US  WWTXD    1.35    1.37    1.39     1.44     1.55
# 301       2018F    US  WWTXV  449.50  458.80  489.30   515.30   557.50
# 302       2018F    US  WXICD    4.14    3.97    4.23     4.63     4.63
# 303       2018F    US  WXICV  105.60  115.40  126.60   178.10   174.30
#
#         1975     1976  ...      2009      2010      2011      2012      2013  \
# ...

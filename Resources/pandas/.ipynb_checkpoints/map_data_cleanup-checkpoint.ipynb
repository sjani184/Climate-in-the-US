# %%
import pandas as pd
import os

# %%
coal = pd.read_csv("../../data/powerplant_coal_2020.csv")
geothermal = pd.read_csv("../../data/powerplant_geothermal_2020.csv")
hydro = pd.read_csv("../../data/powerplant_hydro_2020.csv")
nuclear = pd.read_csv("../../data/powerplant_nuclear_2020.csv")
solar = pd.read_csv("../../data/powerplant_solar_2020.csv")
wind = pd.read_csv("../../data/powerplant_wind_2020.csv")

# %%
frames = [coal, geothermal, hydro, nuclear, solar, wind]

result = pd.concat(frames)

# %%
result
# Out:
#                             FID  ogc_fid                     plant_name  \
# 0        powerplant_coal_2020.1        1                    Dolet Hills
# 1        powerplant_coal_2020.2        2               Charles R Lowman
# 2        powerplant_coal_2020.3        3                         Platte
# 3        powerplant_coal_2020.4        4           Whelan Energy Center
# 4        powerplant_coal_2020.5        5        Aurora Energy LLC Chena
# ...                         ...      ...                            ...
# 1142  powerplant_wind_2020.1143     1143            Palo Alto Wind Farm
# 1143  powerplant_wind_2020.1144     1144  Cuming County Renewables, LLC
# 1144  powerplant_wind_2020.1145     1145                          Cisco
# 1145  powerplant_wind_2020.1146     1146              Lincoln Heights I
# 1146  powerplant_wind_2020.1147     1147             Lincoln Heights II
#
#                          utility_na        sector_nam          city  \
# ...

# %%
result.to_csv("../../data/cleaned/merged_map_data.csv")

# %%
import pandas as pd
import numpy as np

# %%
path = "carbon_emission_by_sector.csv"
transp_df = pd.read_csv(path)
transp_df.dropna()
transp_df.head()
# Out:
#                                      Sector      1975      1980      1985  \
# 0  Total U.S. CO2 Emissions from energy use  4,426.40  4,750.40  4,587.10
# 1                            Transportation  1,291.60  1,400.20  1,421.20
# 2                                      Coal       0.1         0         0
# 3                               Natural gas      31.5      34.5      27.6
# 4                               Electricity       2.1       2.4       2.9
#
#        1990      1991      1992      1993      1994      1995  ...      2010  \
# 0  5,039.90  4,994.60  5,094.90  5,185.80  5,263.60  5,323.20  ...  5,584.60
# 1  1,587.60  1,567.90  1,591.60  1,604.20  1,644.10  1,678.50  ...  1,842.90
# 2         0         0         0         0         0         0  ...         0
# 3        36      32.9      32.3      34.2      37.6      38.4  ...      38.1
# 4       3.2       3.2       3.1       3.2       3.3       3.2  ...       4.7
#
#        2011      2012      2013      2014      2015      2016      2017  \
# 0  5,445.70  5,229.00  5,356.00  5,413.20  5,262.90  5,170.40  5,130.70
# 1  1,809.00  1,773.40  1,796.40  1,814.90  1,838.80  1,871.00  1,887.50
# 2         0         0         0         0         0         0         0
# 3      38.9      41.4      47.1      40.3      39.5      40.2      42.4
# 4       4.4         4       4.2       4.2       3.9       3.6       3.5
#
#        2018      2019
# 0  5,280.90  5,130.50
# 1  1,917.80  1,904.90
# 2         0         0
# 3      50.3      51.9
# 4       3.5       3.3
#
# [5 rows x 34 columns]

# %%
new_df = transp_df.reset_index(drop=True).set_index("Sector")
new_df.head()
# Out:
#                                               1975      1980      1985  \
# Sector
# Total U.S. CO2 Emissions from energy use  4,426.40  4,750.40  4,587.10
# Transportation                            1,291.60  1,400.20  1,421.20
# Coal                                           0.1         0         0
# Natural gas                                   31.5      34.5      27.6
# Electricity                                    2.1       2.4       2.9
#
#                                               1990      1991      1992  \
# Sector
# Total U.S. CO2 Emissions from energy use  5,039.90  4,994.60  5,094.90
# Transportation                            1,587.60  1,567.90  1,591.60
# Coal                                             0         0         0
# Natural gas                                     36      32.9      32.3
# Electricity                                    3.2       3.2       3.1
#
#                                               1993      1994      1995  \
# Sector
# Total U.S. CO2 Emissions from energy use  5,185.80  5,263.60  5,323.20
# Transportation                            1,604.20  1,644.10  1,678.50
# Coal                                             0         0         0
# Natural gas                                   34.2      37.6      38.4
# Electricity                                    3.2       3.3       3.2
#
#                                               1996  ...      2010      2011  \
# Sector                                              ...
# Total U.S. CO2 Emissions from energy use  5,512.10  ...  5,584.60  5,445.70
# Transportation                            1,723.80  ...  1,842.90  1,809.00
# Coal                                             0  ...         0         0
# Natural gas                                   39.1  ...      38.1      38.9
# Electricity                                    3.2  ...       4.7       4.4
#
#                                               2012      2013      2014  \
# Sector
# Total U.S. CO2 Emissions from energy use  5,229.00  5,356.00  5,413.20
# Transportation                            1,773.40  1,796.40  1,814.90
# Coal                                             0         0         0
# Natural gas                                   41.4      47.1      40.3
# Electricity                                      4       4.2       4.2
#
#                                               2015      2016      2017  \
# Sector
# Total U.S. CO2 Emissions from energy use  5,262.90  5,170.40  5,130.70
# Transportation                            1,838.80  1,871.00  1,887.50
# Coal                                             0         0         0
# Natural gas                                   39.5      40.2      42.4
# Electricity                                    3.9       3.6       3.5
#
#                                               2018      2019
# Sector
# Total U.S. CO2 Emissions from energy use  5,280.90  5,130.50
# Transportation                            1,917.80  1,904.90
# Coal                                             0         0
# Natural gas                                   50.3      51.9
# Electricity                                    3.5       3.3
#
# [5 rows x 33 columns]

# %%
new_df1 = new_df.T
new_df1.columns
# Out:
# Index(['Total U.S. CO2 Emissions from energy use', 'Transportation', 'Coal',
#        'Natural gas', 'Electricity', 'Petroleum', 'Motor gasoline',
#        'Hydrocrabon gas liquidsa', 'Jet fuel', 'Distillate fuel oil',
#        'Residual fuel oil', 'Lubricants', 'Aviation gas', 'Industrial',
#        'Residential', 'Commercial'],
#       dtype='object', name='Sector')

# %%
new_df1["year"] = new_df1.index

# %%
new_df1.rename(columns={"Total U.S. CO2 Emissions from energy use": "total_emission", "Transportation": "transportation_emission",
                       "Coal": "coal_emission", "Natural gas": "natural_gas_emission", "Electricity": "electricity_emission",
                       "Petroleum": "petroleum_emission", "Motor gasoline": "motor_emission", "Hydrocrabon gas liquidsa":"hydrocrabon_gas_emission",
                       "Jet fuel": "jet_fuel_emission", "Distillate fuel oil": "distillate_fuel_emission", "Residual fuel oil": "residual_fuel_emission",
                       "Lubricants": "lubricant_emission", "Aviation gas": "aviation_gas_emission", "Industrial": "industrial_emission", 
                        "Residential": "residential_emission", "Commercial": "commercial_emission"}, inplace=True)
new_df1.head()
# Out:
# Sector total_emission transportation_emission coal_emission  \
# 1975         4,426.40                1,291.60           0.1
# 1980         4,750.40                1,400.20             0
# 1985         4,587.10                1,421.20             0
# 1990         5,039.90                1,587.60             0
# 1991         4,994.60                1,567.90             0
#
# Sector natural_gas_emission electricity_emission petroleum_emission  \
# 1975                   31.5                  2.1           1,257.90
# 1980                   34.5                  2.4           1,363.30
# 1985                   27.6                  2.9           1,390.80
# 1990                     36                  3.2           1,548.40
# 1991                   32.9                  3.2           1,531.90
#
# Sector motor_emission hydrocrabon_gas_emission jet_fuel_emission  \
# 1975            888.6                      2.7             144.7
# 1980            881.3                      1.1             155.4
# 1985            907.9                      1.9             177.9
# 1990            966.8                      1.4             222.6
# 1991            962.4                      1.3             215.2
#
# Sector distillate_fuel_emission residual_fuel_emission lubricant_emission  \
# 1975                      155.2                     56                5.7
# 1980                      204.4                  110.2                6.4
# 1985                      231.9                   61.9                5.8
# 1990                      267.8                   80.1                6.5
# 1991                      263.4                   80.8                5.8
#
# Sector aviation_gas_emission industrial_emission residential_emission  \
# 1975                     4.9            1,684.70                867.3
# 1980                     4.5            1,777.00                911.4
# 1985                     3.5            1,552.70                908.7
# 1990                     3.1            1,696.60                963.2
# 1991                     2.9            1,652.20                980.1
#
# Sector commercial_emission  year
# 1975                 582.9  1975
# 1980                 661.9  1980
# 1985                 704.5  1985
# 1990                 792.5  1990
# 1991                 794.3  1991

# %%
path1 = "renewable_energy_consumption.csv"
carbon_df = pd.read_csv(path1)
carbon_df1 = carbon_df.dropna()
carbon_df1.rename(columns={"Annual Total": "year"}, inplace=True)
carbon_df1.head()
# Out:
#    year  Wood Energy Production  Biofuels Production  \
# 0  1990                2216.166              110.867
# 1  1991                2214.082              128.000
# 2  1992                2313.471              145.005
# 3  1993                2259.774              169.336
# 4  1994                2323.820              188.391
#
#    Total Biomass Energy Production  Total Renewable Energy Production  \
# 0                         2735.112                           6040.024
# 1                         2781.797                           6067.785
# 2                         2931.678                           5820.556
# 3                         2908.446                           6081.909
# 4                         3027.534                           5987.142
#
#    Hydroelectric Power Consumption  Geothermal Energy Consumption  \
# 0                         3046.391                        170.747
# 1                         3015.943                        177.626
# 2                         2617.436                        178.699
# 3                         2891.613                        185.673
# 4                         2683.457                        173.464
#
#    Solar Energy Consumption  Wind Energy Consumption  Wood Energy Consumption  \
# 0                    58.768                   29.007                 2216.166
# 1                    61.623                   30.796                 2214.082
# 2                    62.880                   29.863                 2313.471
# 3                    65.190                   30.987                 2259.774
# 4                    67.126                   35.560                 2323.820
#
#    Waste Energy Consumption  Biofuels Consumption  \
# 0                   408.079               110.867
# 1                   439.715               128.000
# 2                   473.202               145.005
# 3                   479.336               169.062
# 4                   515.323               188.391
#
#    Total Biomass Energy Consumption  Total Renewable Energy Consumption
# 0                          2735.112                            6040.024
# 1                          2781.797                            6067.785
# 2                          2931.678                            5820.556
# 3                          2908.172                            6081.635
# 4                          3027.534                            5987.142

# %%
path = "carbon_emission_by_sector.csv"
transp_df = pd.read_csv(path)

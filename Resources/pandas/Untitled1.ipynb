# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
lsd = pd.read_csv("../../data/cleaned/merged_energy_emission.csv")
lsd.head()
# Out:
#    Unnamed: 0  year total_emission transportation_emission  coal_emission  \
# 0           0  1990       5,039.90                1,587.60              0
# 1           1  1991       4,994.60                1,567.90              0
# 2           2  1992       5,094.90                1,591.60              0
# 3           3  1993       5,185.80                1,604.20              0
# 4           4  1994       5,263.60                1,644.10              0
#
#    natural_gas_emission  electricity_emission petroleum_emission  \
# 0                  36.0                   3.2           1,548.40
# 1                  32.9                   3.2           1,531.90
# 2                  32.3                   3.1           1,556.20
# 3                  34.2                   3.2           1,566.90
# 4                  37.6                   3.3           1,603.20
#
#   motor_emission  hydrocrabon_gas_emission  ...  \
# 0          966.8                       1.4  ...
# ...

# %%
columns = ["Unnamed: 0", "coal_emission"]
lsd.drop(columns, axis=1, inplace=True)

# %%
lsd.head()
# Out:
#    year total_emission transportation_emission  natural_gas_emission  \
# 0  1990       5,039.90                1,587.60                  36.0
# 1  1991       4,994.60                1,567.90                  32.9
# 2  1992       5,094.90                1,591.60                  32.3
# 3  1993       5,185.80                1,604.20                  34.2
# 4  1994       5,263.60                1,644.10                  37.6
#
#    electricity_emission petroleum_emission motor_emission  \
# 0                   3.2           1,548.40          966.8
# 1                   3.2           1,531.90          962.4
# 2                   3.1           1,556.20          979.1
# 3                   3.2           1,566.90          993.1
# 4                   3.3           1,603.20       1,004.10
#
#    hydrocrabon_gas_emission  jet_fuel_emission  distillate_fuel_emission  ...  \
# 0                       1.4              222.6                     267.8  ...
# ...

# %%
from sklearn.datasets import make_regression

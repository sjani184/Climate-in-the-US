# %%
import pandas as pd
import requests
import wbpy
from pprint import pprint
import json
import csv

# %%
wb_us = pd.read_csv("data/worldbank_data3.csv")

# %%
wb_us
# Out:
#                                         Country Name Country Code  \
# 0                                      United States          USA
# 1                                      United States          USA
# 2                                      United States          USA
# 3                                      United States          USA
# 4                                      United States          USA
# ..                                               ...          ...
# 75                                               NaN          NaN
# 76                                               NaN          NaN
# 77                                               NaN          NaN
# 78  Data from database: World Development Indicators          NaN
# 79                          Last Updated: 10/15/2020          NaN
#
#                                           Series Name           Series Code  \
# 0   Adjusted savings: carbon dioxide damage (% of ...     NY.ADJ.DCO2.GN.ZS
# ...
